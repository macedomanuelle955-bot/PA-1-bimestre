# %% [markdown]
# <a href="https://colab.research.google.com/github/macedomanuelle955-bot/programa-o/blob/main/aula5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Entrada
# mostrar os graus celsius
#
# #Processamento
# F= C* (9/5) + 32
#
# #Saída
# mostrar graus após conversão em Fahrenheit

# %%
#Escrever um programa que recebe a temperatura em graus celsius e a converte para Farenheit

#Entrada

print ("----------Conversor de Temperatura----------")
print()
celsius =float (input("Digite a temperatura em graus celsius: "))

#Processamento
Farenheit = celsius * (9/5) + 32

#Saída

print ("----------Conversão em farenheit----------")
print()
print(f"A temperatura em Farenheit é: {Farenheit}")
# Out:
# ----------Conversor de Temperatura----------
#
# Digite a temperatura em graus celsius: 25
# ----------Conversão em farenheit----------
#
# A temperatura em Farenheit é: 77.0
