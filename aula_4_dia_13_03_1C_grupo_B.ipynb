# %% [markdown]
# <a href="https://colab.research.google.com/github/macedomanuelle955-bot/programa-o/blob/main/aula_4_dia_13_03_1C_grupo_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# calcular a área do retângulo

# entrada

comprimento= float (input("digite o comprimento:"))
altura= float (input("digite a altura"))

# processamento

area= comprimento * altura

# saída
print(f"o total da área do retângulo é igual a: {area}")
# Out:
# digite o comprimento:5
# digite a altura3
# o total da área do retângulo é igual a: 15.0

# %%
# escrever um programa que faça cálculos aritméticos

# entrada

a= int (input("digite o primeiro número"))
b= int (input("digite o segundo número"))

# processamento
soma= a + b
subtracao= a - b
multiplicacao= a * b
divisao= a / b
div_int= a // b
resto= a % b

# saída

print("---------------CALCULADORA SIMPLES---------------")
print("")
print ("---------------soma---------------")
print("")
print (f"o resultado da soma de {a} mais {b} é igual a:{soma}")
print("")
print("---------------subtração---------------")
print("")
print(f"o resultado da subtração de {a} menos {b} é igual: {subtracao}")
print("")
print("---------------multiplicação---------------")
print("")
print (f"o resultado da multiplicação de {a} vezes {b} é igual:{multiplicacao}")
print("")
print("---------------divisão---------------")
print("")
print(f"o resultado da divisão de {a} dividido por {b} é igual: {divisao}")
print("")
print("---------------divisão inteira---------------")
print("")
print(f"o resultado da divisão inteira de {a} dividido por {b} é igual: {div_int}")
print("")
print("---------------resto da divisão---------------")
print("")
print(f"o resultado do resto da divisão de {a} dividido por {b} é igual: {resto}")
# Out:
# digite o primeiro número25
# digite o segundo número12
# ---------------CALCULADORA SIMPLES---------------
#
# ---------------soma---------------
#
# o resultado da soma de 25 mais 12 é igual a:37
#
# ---------------subtração---------------
#
# o resultado da subtração de 25 menos 12 é igual: 13
#
# ---------------multiplicação---------------
#
# o resultado da multiplicação de 25 vezes 12 é igual:300
#
# ---------------divisão---------------
#
# o resultado da divisão de 25 dividido por 12 é igual: 2.0833333333333335
#
# ---------------divisão inteira---------------
#
# o resultado da divisão inteira de 25 dividido por 12 é igual: 2
#
# ---------------resto da divisão---------------
#
# o resultado do resto da divisão de 25 dividido por 12 é igual: 1

# %% [markdown]
# Escrever um proframa que recebe a temperatura em graus celsius e converte para fahrenheit
# #entrada: graus celsius
#
# #processamento:
# F = C x 9/5) +32
#
# #saida
# mostrar graus em fahrenheit
