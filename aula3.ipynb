# %% [markdown]
# <a href="https://colab.research.google.com/github/macedomanuelle955-bot/programa-o/blob/main/aula3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# aula de programação e algoritmo
#
# * Calcular a área de uma sala
#
# # entrada
#
# Medir o comprimento da sala
# Medir a largura da sala
#
# # processamento
#
# fazer a multiplicação do comprimento pela largura
#
# #Saida
#
# mostrar o resultado

# %%
# entrada

comprimento = 7 # metros
largura = 4 # metros

# %%
# processamento

area = comprimento *  largura

# %%
print (f"area total da sala é: {area} metros quadrados")
# Out:
# area total da sala é: 28 metros quadrados

# %%
# entrada

lado = 2

# processamento

resultado = lado * lado

# saída

print (f" o resultado do quadrado é : {resultado}")
# Out:
#  o resultado do quadrado é : 4

# %% [markdown]
# Atividade:
# Escrever um algoritmo e depois o programa que recebe um numero e calcula o dobro desse numero

# %% [markdown]
# # entrada
# ler um número
#
# # processamento
# fazer a multiplicação por dois
#
# # saída
#
# mostrar o resultado

# %%
# entrada

numero = 4

# processamento

dobro = numero * 2

# saída
print(f"o dobro do numero digitado é: {dobro}")
# Out:
# o dobro do numero digitado é: 8

# %% [markdown]
# Operadores aritméticos
#
# Soma = +
# Subtração = -
# Multiplicação = *
# Divisão = /

# %% [markdown]
# Escrever um algoritmo e o programa que receba 4 notas de alunos e calcula a media dessas notas e mostrar a media

# %% [markdown]
# # entrada
